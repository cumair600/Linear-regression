# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Loading Data into dataframe

# %%
data = pd.read_csv('data/ex1data1.txt', sep=",", header=None)
data.columns = ["Population", "Profit"]
data
# Out:
#     Population    Profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# # Plotting Scattered data

# %%
plt.scatter(data.Population, data.Profit, label= "cross", color= "red",  
            marker= "x", s=30) 
  
plt.ylabel('Profit in $10,000s')  
plt.xlabel('Population of city in $10,000s') 
plt.title('Scattered Plot') 
plt.legend() 
plt.show()

# %% [markdown]
# # Gradient Descent

# %%
w0 = 1
w1 = 1
m = data.Population.size

for j in range(1000):
    print("Iteration : " + str(j))
    y_i = np.array([])
    # dot product
    for i in range(m):
        dot = w0 + w1 * data.Population[i]
        y_i = np.append(y_i, dot, axis=None)

    # loss calculation
    loss = np.array([])
    for i in range(m):
        l = (y_i[i] - data.Profit[i])**2
        loss = np.append(loss, l)
    loss = loss.sum()    
    loss = 1/(2*m) * (loss)
    print("loss : " + str(loss))

    #update weights
    u = np.array([])
    alpha = 0.001
    for i in range(m):
        l = (y_i[i] - data.Profit[i]) * data.Population[i]
        u = np.append(u, l)
    u = u.sum()
    w0 = w0 - alpha*(1/m)*1
    w1 = w1 - alpha*(1/m)*u
# Out:
# Iteration : 0
# loss : 10.266520491383504
# Iteration : 1
# loss : 9.703063744622737
# Iteration : 2
# loss : 9.227608833469782
# Iteration : 3
# loss : 8.8264113658177
# Iteration : 4
# loss : 8.487873578773318
# Iteration : 5
# loss : 8.202209074340663
# Iteration : 6
# loss : 7.961159917197994
# Iteration : 7
# loss : 7.75775791658273
# Iteration : 8
# loss : 7.5861231915474345
# Iteration : 9
# loss : 7.441294196616447
# Iteration : 10
# loss : 7.319084294312244
# Iteration : 11
# loss : 7.215960728422514
# Iteration : 12
# loss : 7.128942499427186
# Iteration : 13
# loss : 7.055514189917736
# Iteration : 14
# loss : 6.993553248914831
# Iteration : 15
# loss : 6.941268633052892
# Iteration : 16
# loss : 6.897149030898405
# Iteration : 17
# loss : 6.859919173692978
# Iteration : 18
# loss : 6.828502969570317
# Iteration : 19
# loss : 6.8019923955458
# Iteration : 20
# loss : 6.779621248020098
# Iteration : 21
# loss : 6.76074299298586
# Iteration : 22
# loss : 6.744812075638661
# ...

# %%
plt.plot(data.Population, y_i, label= "prediction", color= "blue")
plt.scatter(data.Population, data.Profit, label= "actual data", color= "red",  
            marker= "x", s=30) 
  
plt.ylabel('Profit in $10,000s')  
plt.xlabel('Population of city in $10,000s') 
plt.title('Trained Model') 
plt.legend() 
plt.show()
